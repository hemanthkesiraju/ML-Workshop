# %%
# improt libraries
import numpy as np #for fater data processing(arrys)
improt pandas as pd #EDA uses
# Out:
#   Cell In[1], line 3
#     improt pandas as pd #EDA uses
#            ^
# SyntaxError: invalid syntax

# %%
# Import libraries
import numpy as np      # For faster data processing (arrays)
import pandas as pd     # For EDA (Exploratory Data Analysis)

# %%
#loading the data
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#understanding the data set 
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %%
#reading cmls
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
# seperate the cmls
data.dtypes;
data.select_dtypes(include='object')
data.select_dtypes(include=['int','float'])
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10316\1806012880.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ...

# %%
#getting tot number of passengers in ship
print('total number of passenegers in the ship are', len(data))
# Out:
# total number of passenegers in the ship are 891

# %%
#stastical disrtibution--> describe()
data.describe() #default--> numerical value only
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object')
# top returns most occuring value 
# freq returns the count of the most occuring value
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10316\141379509.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
# try to konw the unique values in the cmls
data['Sex'].unique()
# Out:
# <ArrowStringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
data['Name'].unique()
# Out:
# <ArrowStringArray>
# [                            'Braund, Mr. Owen Harris',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#                               'Heikkinen, Miss. Laina',
#         'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#                             'Allen, Mr. William Henry',
#                                     'Moran, Mr. James',
#                              'McCarthy, Mr. Timothy J',
#                       'Palsson, Master. Gosta Leonard',
#    'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#                  'Nasser, Mrs. Nicholas (Adele Achem)',
#  ...
#                                   'Markun, Mr. Johann',
#                         'Dahlberg, Miss. Gerda Ulrika',
#                        'Banfield, Mr. Frederick James',
#                               'Sutehall, Mr. Henry Jr',
#                 'Rice, Mrs. William (Margaret Norton)',
#                                'Montvila, Rev. Juozas',
# ...

# %%
data['Embarked'].unique()
# Out:
# <ArrowStringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
#count of each unique value
data['Sex'].value_counts();

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
#to get any random samples in the dataset 
data.sample(15)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 222          223         0       3                    Green, Mr. George Henry
# 401          402         0       3                            Adams, Mr. John
# 475          476         0       1                Clifford, Mr. George Quincy
# 678          679         0       3    Goodwin, Mrs. Frederick (Augusta Tyler)
# 555          556         0       1                         Wright, Mr. George
# 578          579         0       3           Caram, Mrs. Joseph (Maria Elias)
# 585          586         1       1                        Taussig, Miss. Ruth
# 158          159         0       3                        Smiljanic, Mr. Mile
# 802          803         1       1        Carter, Master. William Thornton II
# 495          496         0       3                      Yousseff, Mr. Gerious
# 815          816         0       1                           Fry, Mr. Richard
# ...

# %%
#datavisulizatin-->matplotlib,seborn,pyplot
import matplotlib.pyplot as plt

# %%
#distrubution of age
plt.hist(data['Age'],bins=15,color='blue')
plt.title("Age Distribution")
plt.show()

# %%
# display the count on bars in histrogram
counts,edeges,bars=plt.hist(data['Age'],bins=15,color='blue')
print(counts)
print(bars)
plt.bar_label(bars)
plt.title("Age Distribution")
plt.show()
# Out:
# [ 44.  24.  32. 104. 115. 127.  80.  59.  49.  30.  22.  17.   4.   6.
#    1.]
# <BarContainer object of 15 artists>

# %%
# bar plot's
data['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
data['Pclass'].value_counts().plot(kind='barh',color='blue')# bar horiszontal
# Out:
# <Axes: ylabel='Pclass'>

# %%
plt.bar(data['Survived'],data['Sex'])
plt.xlabel("survived Rate")
plt.ylabel("Gender")
plt.title("Gender  Survived disrtibution")
plt.show()

# %%
#to show % ratio
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
index=data['Survived'].value_counts().keys()
print(index)
labels=data['Survived'].value_counts().values.tolist()
print(labels)

# %%
# pie chat
plt.pie(x=labels,
        labels=['Dead', 'Alive'],
        colors=['red', 'green'],
        autopct="%.1f%%")
plt.show()

# %%
labels = data['Survived'].value_counts()

plt.pie(x=labels,
        labels=['Dead', 'Alive'],
        colors=['red', 'green'],
        autopct='%.1f%%')

plt.show()

# %%
labels = data['Survived'].value_counts().sort_index()

plt.pie(x=labels,
        labels=['Dead', 'Alive'],
        colors=['red', 'green'],
        autopct='%.1f%%',
        shadow=True)

plt.legend()
plt.show()

# %%
plt.pie(x = labels, labels = ['Dead','Alive'],
        colors =['red','green'],
        autopct="%.1f%%",
        shadow = True)
plt.title("Susrivived Ditribution")
plt.legend()
plt.show()

# %%
plt.pie(x = [577,314], labels = ['M','F'],
        colors =['red','green'],
        autopct="%.1f%%",
        shadow = True)
plt.title("Gender Ditribution")
plt.legend()
plt.show()

# %%
# Pairwise Relationship
plt.scatter(x=data['Age'], y=data['Fare'], color='red')

plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Age v/s Fare Distribution")

plt.show()

# %%
import plotly

# %%
import plotly as py
import plotly.graph_objects as go # for intractive graphs

# %%
import plotly.graph_objects as go
# Let's visualize the histogram
trace = go.Histogram(
    x=data['Age'],
    nbinsx=20,
    marker={'color': 'red'})

# Layout
layout = go.Layout(
    title="Age Distribution"
)

# Combine the trace with the layout
fig = go.Figure(data=[trace], layout=layout)

# Display the figure
fig.show()

# %%
print (index)
print(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print (index)
#       2 print(labels)
#
# NameError: name 'index' is not defined

# %%
import plotly.graph_objects as go
trace = go.Pie(
    labels=["Dead", "Alive"],
    values=labels,
    hoverinfo="label+value+percent")
layout = go.Layout(
    title="Survived Distribution")
fig = go.Figure(data=[trace], layout=layout)
fig.show()

# %%
#or
trace=go.Pie(labels=['Dead','Alive'],
             values=[549,342],
            )
layout=go.Layout(title='Survived Distribution')
fig = go.Figure(data=trace,layout=layout)
fig.show()

# %%
#box and scatter plots
trace = go.Box(x=data['Pclass'],
               y=data['Age'],
               marker={'color':'Green'})
layout = go.Layout(title ='Age V/S Pcalss distrbuition')
fig = go.Figure(data= trace,layout = layout)
fig.show()

# %%
#Scatter plot representation --> Age vs Fare
trace=go.Scatter(x=data['Age'],y=data['Fare'],mode='markers',marker={'color':'green'})
layout=go.Layout(title='Age vs Fare Distribution')
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
#understanding the misssing values & filing the missing values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#understanding the misssing values & filing the missing values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(data['Age'].mean())
# Out:
# 29.69911764705882

# %%
# Age cml  missing value  can be filled with the  mean
data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10316\3290586713.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data['Embarked']=data['Embarked'].fillna('S',inplace=True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_10316\3156795352.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data['Embarked']=data['Embarked'].fillna('S',inplace=True)

# %%
data.drop(columns=['Cabin'],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#get_dummiespx
pclass = pd.get_dummies(data['Pclass'],drop_first=True,dtype=int)
pclass
# Out:
#      2  3
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  0
# 4    0  1
# ..  .. ..
# 886  1  0
# 887  0  0
# 888  0  1
# 889  0  0
# 890  0  1
#
# [891 rows x 2 columns]

# %%
embarked = pd.get_dummies(data['Embarked'], dtype=int)
embarked
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
# Concatenation of all tables
final_data = pd.concat([data, pclass, embarked], axis=1)

final_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
final_data.drop(columns=['PassengerId', 'Name',
                         'Pclass', 'Sex', 'Ticket',
                         'Embarked'], inplace=True)
final_data
# Out:
#      Survived        Age  SibSp  Parch     Fare  2  3  C  Q  S
# 0           0  22.000000      1      0   7.2500  0  1  0  0  1
# 1           1  38.000000      1      0  71.2833  0  0  1  0  0
# 2           1  26.000000      0      0   7.9250  0  1  0  0  1
# 3           1  35.000000      1      0  53.1000  0  0  0  0  1
# 4           0  35.000000      0      0   8.0500  0  1  0  0  1
# ..        ...        ...    ...    ...      ... .. .. .. .. ..
# 886         0  27.000000      0      0  13.0000  1  0  0  0  1
# 887         1  19.000000      0      0  30.0000  0  0  0  0  1
# 888         0  29.699118      1      2  23.4500  0  1  0  0  1
# 889         1  26.000000      0      0  30.0000  0  0  1  0  0
# 890         0  32.000000      0      0   7.7500  0  1  0  1  0
#
# [891 rows x 10 columns]
